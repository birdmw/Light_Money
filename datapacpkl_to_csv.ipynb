# %%
from leaper import *

# %%
# cloud storage 
filename_IE = 'data\Independent_Campaign_Expenditures_and_Electioneering_Communications20181110.csv'
filename_pac = 'data\Contributions_to_Candidates_and_Political_Committees20181110.csv'
config_file = 'config.yml'

df = IEnPAC_to_csv(filename_IE, filename_pac, config_file)

# Dataframe to table
# Out:
# (1089, 10)
# C:\Users\birdm\Anaconda2\lib\site-packages\ipykernel_launcher.py:5: DtypeWarning: Columns (23,33,34) have mixed types. Specify dtype option on import or set low_memory=False.
#   """
# (60845, 12)
# (58365, 12)
# (58365, 12)
# 1550365339.03
# 58365
# Meow
# 216.881999969
# 19278
# Make manual corrections
# Converting data_ie.all_candidates.keys() to match data_pac.all_candidates.keys()
# leaper.py:850: FutureWarning: from_items is deprecated. Please use DataFrame.from_dict(dict(items), ...) instead. DataFrame.from_dict(OrderedDict(items)) may be used to preserve the key order.
#   cand_change = pd.DataFrame.from_items([('oldnames', oldname), ('newnames', newname)])
# Finding matches between data_ie.all_donors.keys() and data_pac.all_donors.keys()
# leaper.py:870: FutureWarning: from_items is deprecated. Please use DataFrame.from_dict(dict(items), ...) instead. DataFrame.from_dict(OrderedDict(items)) may be used to preserve the key order.
#   donor_change = pd.DataFrame.from_items([('oldnames', oldname), ('newnames', newname)])
# SULLIVAN PATRICK J
# C:\Users\birdm\Anaconda2\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\birdm\Anaconda2\lib\site-packages\pandas\core\frame.py:6211: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
# VAN WERVEN LUANNE E
# PEDERSEN JAMIE D
# HARRISON NOAH F
# No Match - skipped:
# DALZELL JUELIE B
# -0.0
# FRANCIK REBECCA A
# STANFORD DEREK C
# FRENCH ALFRED G II
# SALDANA REBECCA J
# BROWN STEVE D
# GOEHNER KEITH W
# PEACH WILLIAM W
# PELLICCIOTTI MICHAEL J
# VICK BRANDON P
# TAYLOR DAVID V
# TOM RODNEY
# WALSH JAMES W
# GOULET JENNIFER D
# KRETZ JOEL A
# GRAVES PAUL S
# FAIN JOSEPH F
# HARRIS TANISHA L
# KILDUFF CHRISTINE J
# STANFORD JOY
# MAGENDANZ CHAD L
# KUNEY MARY L
# PARIS PATRICIA A
# WALEN AMY D
# RAMOS BILL G
# MILOSCIA MARK A
# GRAHAM VIRGINIA C
# RADZIMSKI LECH J
# No Match - skipped:
# KRISTIANSON  LARRY M
# 669.0
# SLATTER VANDANA
# BLAKE WALTER (BUD) T
# PADULA ELIZABETH A
# No Match - skipped:
# III BRANCHES LAW
# 500.0
# SAWYER DAVID J
# MCMULLEN SCOTT T
# MAYCUMBER JACQUELIN M
# CHOPP FRANK V
# SHORT SHELLY A
# VOLZ JAMES M
# NGUYEN JOSEPH-THANH T
# GONZALEZ STEVEN C
# DAVIS LAUREN
# STONIER MONICA J
# FITZGERALD TIMOTHY W
# GILLESPIE KATHY E
# WOLFE REBECCA J
# ANDERSON MARCINE S
# GILDON CHRIS
# ERICKSEN DOUGLAS J
# THARINGER STEPHEN P
# MCCLENDON MARTIN V
# DOLAN LAURIE H
# KOCHMAR LINDA L
# ORTIZ-SELF LILLIAN
# WILSON DAVID J
# OOSTERMAN LINDA L
# BALLEW TIMOTHY J II
# DETRO JAMES G
# HASKELL LAWRENCE H
# LUCAS DAVID
# ORMSBY TIMM S
# BROTHERTON GREGORY A
# No Match - skipped:
# HUNTER RAYMOND
# -70.0
# SENN TANA D
# MAROON EVERETT
# BENTLEY-FEINBERG SASHA ROSE L
# DHINGRA MANKA
# BRADDOCK SHANNON
# MACEWEN DREW C
# MENA VICTORIA
# ROULSTONE DOUGLAS R
# WALKER MINDY L
# No Match - skipped:
# DALZELL JUELIE B
# 984.38
# QUIRING EILEEN J
# LOVICK JOHNNY R
# GRIFFEY DANIEL G
# SHELDON TIMOTHY M
# BOSS RANDY
# SMALL SHON R
# HAYES DAVID J
# CHAMBERS KELLY M
# MORGAN MELANIE V
# COOPER ANGELA J
# POLLET GERALD M
# HOBBS STEVEN R
# ENTENMAN DEBRA J
# KLOBA SHELLEY A
# SMITH JAMIE L
# YOUNG JESSE L
# SHUMWAY LINDSEY E
# WILKE JODI M
# BOWLING IRENE R
# CALDIER MICHELLE D
# WEIKER WENDY L
# REEVES KRISTINE M
# DUTHIE BRIAN S
# HOLY JEFFREY M
# WILSON CLAIRE E
# WITTING NED W
# FITZPATRICK CONSTANCE M
# PONOMARCHUK LEONID
# VALDEZ JAVIER
# LEKANOFF DEBRA E
# CHRISTOPHER DWAYNE L
# No Match - skipped:
# III BRANCHES LAW
# 500.0
# HAYDEN RANDOLPH J
# RICCELLI MARCUS M
# WAGONER KEITH L
# FRASIER ERIN M
# MURI RICHARD W
# PETERSON STROM H
# LEWIS JESSA
# HARMSWORTH MARK J
# CHRISTIAN LEONARD G
# MURANO KAY E
# SCHMICK JOSEPH S
# MACRI NICOLE
# FERRERIA IMMACULATE
# TRASK SHARON K
# VARGAS PINKY T
# BREWER TERRY L
# MANWELLER MATHEW S
# KEISER KAREN L
# SMITH NORMA C
# HAMMOND SYLVIA
# ROBNETT MARY E
# No Match - skipped:
# III BRANCHES LAW
# 10005.0
# NOLE JOE
# No Match - skipped:
# HUNTER RAYMOND
# -70.0
# BUYS VINCENT K
# KONIS THOMAS F
# FROCKT DAVID S
# CUMMINGS TED F
# ROLLINS MARY F
# HOFF LARRY A
# FOSTER JEFFREY B
# MCENTIRE JAMES F
# KUDERER PATRICIA E
# HARDY KAREN L
# THAI MY-LINH T
# NOMA ARIAN E
# LOGAN SIDNEY M
# MCCOY JOHN R
# KRAFT VICKI C
# MENSER SAMUEL T
# RUDE SKYLER D
# CAMPAGNA JOSEPH A
# CALLAN LISA M
# SALOMON JESSE M
# DIAMOND ANN
# SHEERAN JOHN M
# No Match - skipped:
# COMMITTEE FOR JUDICIAL READINESS
# -9293.43
# HALVORSON ERIC
# PAUL DAVID M
# MEAD JARED M
# KRUGER LEAVITT MARI L
# DAS MONA
# WILLIAMS KARL L
# No Match - skipped:
# III BRANCHES LAW
# 500.0
# HARGROVE MARK D
# KNEZOVICH OZZIE D
# CHASE MARALYN
# No Match - skipped:
# FRIENDS OF ELAINE PHELPS
# 5000.0
# SHEWMAKE SHARON A
# STEELE MICHEAL A
# BLAKE BRIAN E
# STEWART JEANNE E
# RANDALL EMILY E
# WA REALTORS PAC
# ASSN OF WA BUSINESS PAC
# CIT FOR BETTER SCHOOLS BATTLE GROUND
# CIT TO RECALL PEPPER
# CIVIC ALLIANCE FOR A SOUND ECONOMY SPONSORED BY THE SEATTLE CHAMBER
# ENTERPRISE WASHINGTON
# resolve_donations: Recursion loop, ignoring donation to self by ENTERPRISE WASHINGTON
# MAINSTREAM REPUB OF WA ST PAC
# THURSTON CO REPUB CENT COMM NON EXEMPT
# HARRY TRUMAN FUND
# AB PAC
# CLARK CO DEMO CENT COMM EXEMPT
# LM PAC
# LOCAL DEMOCRATIC ORGS
# COWLITZ CO DEMO CENT COMM NON EXEMPT
# FOR 940
# FAMILIES YES
# KING CO DEMO CENT COMM NON EXEMPT
# KITSAP CO DEMO CENT COMM NON EXEMPT
# LAKE WA CIT LEVY COMM
# resolve_donations: Recursion loop, ignoring donation to self by LOCAL DEMOCRATIC ORGS
# MASON CO DEMO CENT COMM NON EXEMPT
# PIERCE CO DEMO CENT COMM NON EXEMPT
# RIVERVIEW SCHOOLS COMM
# SNOHOMISH COUNTY DEMOCRATS
# EVERETT DISTRICTS NOW
# resolve_donations: Recursion loop, ignoring donation to self by EVERETT DISTRICTS NOW
# resolve_donations: Recursion loop from LOCAL DEMOCRATIC ORGS to SOUTH KING COUNTY DEMOCRATS
# From: 30.02  To: 100.0
# SOUTH KITSAP SCHOOL SUPPORTERS
# SPOKANE CO DEMO CENT COMM NON EXEMPT
# STAND UP FOR PENINSULA SCHOOLS
# resolve_donations: Recursion loop from LOCAL DEMOCRATIC ORGS to WA STATE DEMOCRATIC PARTY
# From: 4328.49  To: 1354.8600000000001
# WA STATE DEMOCRATIC PARTY
# CLARK CO DEMO CENT COMM NON EXEMPT
# ISLANDERS YES
# NEIGHBORS FOR BELLINGHAM HOME FUND
# SPOKANE CO DEMO CENT COMM EXEMPT
# TACOMA CIT FOR SCHOOLS
# THE FIRST AMERICAN PROJECT
# YES FOR HOMES COALITION OF SAN JUAN CO
# YES LIBRARIES PIERCE
# MAINSTREAM VOTERS OF WA
# ENOUGH IS ENOUGH PAC
# NATL WOMENS POLITICAL CAUCUS OF WA CAMP FUND
# NEW DIRECTION PAC
# CHILDRENS CAMPAIGN FUND
# EASTSIDE LEADERSHIP COUNCIL
# OURVOTESCOUNT
# resolve_donations: Recursion loop from NEW DIRECTION PAC to SEIU 775
# From: 2898.17  To: 102898.17
# SOUTH SOUND WOMENS LEADERSHIP PAC
# SOUTHWEST WA PRIORITIES
# SPOKANE LEADERSHIP COUNCIL
# resolve_donations: Recursion loop from NEW DIRECTION PAC to WASHINGTON CONSERVATION VOTERS
# From: 756.0  To: 100000.0
# WASHINGTON WORKS PAC
# WASHINGTON WORKS FOR US PAC
# SOUTH KING COUNTY DESERVES BETTER
# SUSTAINABLE FUTURE PAC
# WIN WITH WOMEN
# WASHINGTON VALUES PAC
# WASHINGTON SENATE DEMOCRATIC CAMPAIGN
# WHATCOM DEMOCRATS
# FOR 1631
# FOR 1639
# WA ST FEDERATION OF DEMO WOMEN
# resolve_donations: Recursion loop, ignoring donation to self by WHATCOM DEMOCRATS
# KENNEDY FUND
# ISLAND PAC
# REAGAN FUND
# CONCERNED TAXPAYERS OF WASHINGTON STATE
# EVERGREEN PROGRESS
# KING COUNTY REPUBLICAN PARTY
# resolve_donations: Recursion loop, ignoring donation to self by KING COUNTY REPUBLICAN PARTY
# QUALITY COMMUNITIES COMM (REAGAN FUND)
# SNOHOMISH COUNTY REPUBLICAN PARTY
# AGAINST 940
# AGAINST 1631
# LOCAL REPUBLICAN ORGS
# resolve_donations: Recursion loop, ignoring donation to self by LOCAL REPUBLICAN ORGS
# PIERCE CO REPUB CENT COMM NON EXEMPT
# TRUTH FOR WA SPONSOR WORKING FAMILIES OF KING CO
# resolve_donations: Recursion loop from LOCAL REPUBLICAN ORGS to WHATCOM REPUBLICANS
# From: 11630.0  To: 4000.0
# WHATCOM REPUBLICANS
# AGAINST 1639
# resolve_donations: Recursion loop, ignoring donation to self by WHATCOM REPUBLICANS
# WORKING FAMILIES OF KING CO
# resolve_donations: Recursion loop from SNOHOMISH COUNTY REPUBLICAN PARTY to WA STATE REPUBLICAN PARTY
# From: 5000.0  To: 1650.0
# WA STATE REPUBLICAN PARTY
# SPOKANE CO REPUB CENT COMM NON EXEMPT
# STEVENS CO REPUB CENT COMM NON EXEMPT
# STEVENS COUNTY REPUBLICAN CENTRAL COMMITTEE EXEMPT ACCOUNT
# TACOMA-PIERCE CO BUSINESS ALLIANCE PAC
# resolve_donations: Recursion loop, ignoring donation to self by WA REALTORS PAC
# COCA COLA NORTH AMERICA
# FOR 1634
# PEPSI COLA NW BUSINESS UNIT
# WASHINGTON BEVERAGE ASSOCIATION
# THE LEADERSHIP COUNCIL
# WA FORWARD (THE LEADERSHIP COUNCIL)
# DR PEPPER SNAPPLE GROUP
# WA HOSPITALITY ASSOCIATION
# HOUSE DEMOCRATIC CAUCUS CAMPAIGN COMMITTEE
# RETIRED PUBLIC EMPLOYEES COUNCIL OF WA
# HOUSE REPUBLICAN ORGANIZATION COMMITTEE
# CHELAN CO REPUB CENT COMM
# SEATTLE HOSPITALITY FOR PROGRESS
# SENATE REPUBLICAN CAMPAIGN COMMITTEE
# ANHEUSER BUSCH CO.
# BOEING COMPANY
# BOEING EMPLOYEES CREDIT UNION
# ANDEAVOR
# PHILLIPS 66
# AMERICAN FUEL AND PETROCHEMICAL MANUFACTURERS
# BP AMERICA
# BP AMERICA EMPLOYEE PAC
# WEYERHAEUSER CO
# WA FOREST PROTECTION ASSN ST PAC
# WA SELF INSURERS ASSN LEG FUND
# KOCH INDUSTRIES, INC.
# WASHINGTON EDUCATION ASSOCIATION
# CIT COMM FOR ARLINGTON SCHOOL DIST
# CIT FOR EVERETT PUBLIC SCHOOLS
# CIT FOR SUPPORT OF YELM SCHOOLS
# CITIZENS TEAM FOR MUKILTEO SCHOOLS
# SUPPORT FERNDALE SCHOOLS COMM
# VOICE OF TAHOMA EDUCATION
# resolve_donations: Recursion loop, ignoring donation to self by WASHINGTON EDUCATION ASSOCIATION
# MUCKLESHOOT INDIAN TRIBE
# NATIVE WOMENS PAC
# C:\Users\birdm\Anaconda2\lib\site-packages\ipykernel_launcher.py:23: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated

# %%
df.head(50)
# Out:
#                                 0                                       1  \
# 0                   OURVOTESCOUNT                           CALLAN LISA M
# 1                   OURVOTESCOUNT                                DAS MONA
# 2                   OURVOTESCOUNT                        ENTENMAN DEBRA J
# 3                   OURVOTESCOUNT                     KILDUFF CHRISTINE J
# 4                   OURVOTESCOUNT                   KRUGER LEAVITT MARI L
# 5                   OURVOTESCOUNT                  PELLICCIOTTI MICHAEL J
# 6                   OURVOTESCOUNT                            RAMOS BILL G
# 7                   OURVOTESCOUNT                       REEVES KRISTINE M
# 8                   OURVOTESCOUNT                      SULLIVAN PATRICK J
# 9                   OURVOTESCOUNT                         WILSON CLAIRE E
# 10                  OURVOTESCOUNT                           OURVOTESCOUNT
# 11  MAINSTREAM REPUB OF WA ST PAC                        CHAMBERS KELLY M
# 12  MAINSTREAM REPUB OF WA ST PAC                         ESPINOZA MAIA L
# 13  MAINSTREAM REPUB OF WA ST PAC                           FAIN JOSEPH F
# 14  MAINSTREAM REPUB OF WA ST PAC                            GILDON CHRIS
# 15  MAINSTREAM REPUB OF WA ST PAC                         GOEHNER KEITH W
# 16  MAINSTREAM REPUB OF WA ST PAC                       GRAHAM VIRGINIA C
# 17  MAINSTREAM REPUB OF WA ST PAC                           GRAVES PAUL S
# 18  MAINSTREAM REPUB OF WA ST PAC                       HAYDEN RANDOLPH J
# 19  MAINSTREAM REPUB OF WA ST PAC                           HAYES DAVID J
# 20  MAINSTREAM REPUB OF WA ST PAC                            HOFF LARRY A
# 21  MAINSTREAM REPUB OF WA ST PAC                      KUDERER PATRICIA E
# 22  MAINSTREAM REPUB OF WA ST PAC                            KUNEY MARY L
# 23  MAINSTREAM REPUB OF WA ST PAC                        MAGENDANZ CHAD L
# 24  MAINSTREAM REPUB OF WA ST PAC                         MILOSCIA MARK A
# 25  MAINSTREAM REPUB OF WA ST PAC                          MURI RICHARD W
# 26  MAINSTREAM REPUB OF WA ST PAC                     ROULSTONE DOUGLAS R
# 27  MAINSTREAM REPUB OF WA ST PAC                           RUDE SKYLER D
# 28  MAINSTREAM REPUB OF WA ST PAC  THURSTON CO REPUB CENT COMM NON EXEMPT
# 29  MAINSTREAM REPUB OF WA ST PAC                              TOM RODNEY
# 30  MAINSTREAM REPUB OF WA ST PAC                         WAGONER KEITH L
# 31  MAINSTREAM REPUB OF WA ST PAC                           WALSH JAMES W
# 32             ANHEUSER BUSCH CO.                            AGAINST 1631
# 33             ANHEUSER BUSCH CO.                            AGAINST 1639
# 34             ANHEUSER BUSCH CO.                             AGAINST 940
# 35             ANHEUSER BUSCH CO.                      AGUILAR EVANGELINA
# 36             ANHEUSER BUSCH CO.                            AMETU RION A
# 37             ANHEUSER BUSCH CO.                          ANDREWS PAUL D
# 38             ANHEUSER BUSCH CO.                          ANGEL JANICE E
# 39             ANHEUSER BUSCH CO.                       APPLEBY MICHAEL A
# 40             ANHEUSER BUSCH CO.                       APPLETON SHERRY V
# 41             ANHEUSER BUSCH CO.                          ARAGON SOFIA A
# 42             ANHEUSER BUSCH CO.                        BAILEY BRENNAN F
# 43             ANHEUSER BUSCH CO.                     BALLEW TIMOTHY J II
# 44             ANHEUSER BUSCH CO.                         BARKIS ANDREW K
# 45             ANHEUSER BUSCH CO.                   BAUMGARTNER MICHAEL J
# 46             ANHEUSER BUSCH CO.                          BELL MICHAEL R
# 47             ANHEUSER BUSCH CO.                         BIGEA PETRONELA
# 48             ANHEUSER BUSCH CO.                           BLAKE BRIAN E
# 49             ANHEUSER BUSCH CO.                        BLODGETT DEBRA F
#
#                 2
# 0     5355.620000
# 1    10675.550000
# 2    10675.560000
# 3    15410.750000
# 4    15410.750000
# 5     7131.120000
# 6     5355.620000
# 7     7131.130000
# 8    10181.700000
# 9     6999.140000
# 10  363577.750000
# 11   25490.710000
# 12    1000.000000
# 13    1000.000000
# 14    6890.710000
# 15    1000.000000
# 16    5899.180000
# 17    9764.240000
# 18    6395.770000
# 19   10600.000000
# 20    1000.000000
# 21   -5219.620000
# 22    1000.000000
# 23   54612.870000
# 24   24048.390000
# 25    1000.000000
# 26   18391.290000
# 27    6727.650000
# 28      60.000000
# 29   34503.980000
# 30   22395.770000
# 31   27680.470000
# 32       0.266251
# 33       0.153234
# 34       0.266301
# 35       4.236159
# 36       0.392593
# 37       1.393392
# 38    2006.530717
# 39       0.110842
# 40       0.126471
# 41       0.395098
# 42       0.154821
# 43       0.386483
# 44    2000.000000
# 45    4003.401997
# 46       0.390555
# 47       0.134495
# 48    2001.020356
# 49       0.500993
